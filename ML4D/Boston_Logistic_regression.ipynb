# %%
from sklearn.datasets import load_boston
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import numpy as np

# %%
data = load_boston()

# %%
X = data.data
y = data.target

# %%
binary_y = np.array(y >= 40).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, binary_y, test_size = 0.33, random_state = 5)

# %%
logistic = LogisticRegression()
logistic.fit(X_train, y_train)
# Out:
# /home/abramovich/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
from sklearn.metrics import accuracy_score

# %%
print('in-sample accuracy: %0.3f' % accuracy_score(y_train, logistic.predict(X_train)))
# Out:
# in-sample accuracy: 0.985

# %%
print('out-sample accuracy: %0.3f' % accuracy_score(y_test, logistic.predict(X_test)))
# Out:
# out-sample accuracy: 0.964

# %%
for var, coef in zip(data.feature_names, logistic.coef_[0]):
    print("%7s : %7.3f" %(var, coef))
# Out:
#    CRIM :   0.076
#      ZN :   0.010
#   INDUS :   0.131
#    CHAS :  -0.562
#     NOX :  -0.018
#      RM :   1.678
#     AGE :  -0.003
#     DIS :  -0.197
#     RAD :   0.422
#     TAX :  -0.013
# PTRATIO :  -0.638
#       B :   0.006
#   LSTAT :  -0.803

# %%
print('\n classes:', logistic.classes_)
print('\nProbs:\n', logistic.predict_proba(X_test))
# Out:
#  classes: [0 1]
#
# Probs:
#  [[1.87246774e-01 8.12753226e-01]
#  [9.76211984e-01 2.37880157e-02]
#  [9.99777384e-01 2.22616059e-04]
#  [1.00000000e+00 4.79661661e-12]
#  [9.83114605e-01 1.68853948e-02]
#  [9.99999996e-01 4.00710751e-09]
#  [9.97920020e-01 2.07997955e-03]
#  [9.95635922e-01 4.36407775e-03]
#  [9.99789609e-01 2.10390946e-04]
#  [9.99656116e-01 3.43884208e-04]
#  [9.92927510e-01 7.07249011e-03]
#  [9.99930862e-01 6.91382569e-05]
#  [9.99899028e-01 1.00971588e-04]
#  [9.57326490e-01 4.26735102e-02]
#  [9.98119165e-01 1.88083482e-03]
#  [9.99999548e-01 4.52090611e-07]
#  [1.00000000e+00 8.61430932e-13]
#  [9.99955819e-01 4.41807742e-05]
#  [9.99999998e-01 2.30038958e-09]
#  [9.83451501e-01 1.65484987e-02]
#  [1.00000000e+00 4.43074026e-14]
#  [9.99988001e-01 1.19989262e-05]
#  [2.49211773e-01 7.50788227e-01]
#  [9.99861887e-01 1.38113080e-04]
#  [9.95319844e-01 4.68015623e-03]
#  [9.99999935e-01 6.49538464e-08]
#  [9.98796902e-01 1.20309838e-03]
#  [9.99981111e-01 1.88892127e-05]
#  [9.97785987e-01 2.21401327e-03]
#  [9.99632380e-01 3.67619536e-04]
#  [9.99999997e-01 3.35965557e-09]
#  [1.00000000e+00 8.67727923e-12]
#  [9.99930045e-01 6.99548944e-05]
#  [9.99666074e-01 3.33925556e-04]
#  [9.95601302e-01 4.39869784e-03]
#  [9.99994983e-01 5.01729705e-06]
#  [9.98823108e-01 1.17689188e-03]
#  [9.99999985e-01 1.45681047e-08]
#  [1.16771797e-01 8.83228203e-01]
